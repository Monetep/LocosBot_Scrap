# %%
import pandas as pd
import numpy as np

df = pd.read_csv('dtoid_scrap_2018-08-20_03_44_07.csv', sep = '|')
print(df)
# Out:
#                                                parrafo  \
# 0    Star Fox 64 was one of the first games I ever ...
# 1
# 2    Who likes classic arcades games? Who has a Swi...
# 3    If you answered yes to any of the above questi...
# 4                         I'll let the devs take over:
# 5    Nitro Ball features Gary, an Ex-Navy Sergeant ...
# 6    Win your copy of this arcade classic by commen...
# 7    Switch keys are for the North American eShop o...
# 8    Johnny Turbo's Arcade: Nitro Ball is available...
# 9    I am ecstatic that I can go online today and b...
# 10   This was the reason I once owned a Family Comp...
# 11                                         Holy Diver,
# 12   You're too goddamn hard and and you make me sc...
# 13   Just put my fist through the screen.Grab my li...
# 14                  Gonna set fire to my game machine,
# 15                 The words out my mouth are obscene,
# 16                            'Cause I hate this game,
# ...
